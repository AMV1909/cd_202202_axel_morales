# %% [markdown]
# <a href="https://colab.research.google.com/github/AMV1909/cd_202202_axel_morales/blob/main/Taller%20N%C2%B0%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import colors
from scipy.stats import pearsonr, zscore

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model

# %%
#Datos de hoteles
ruta = 'https://raw.githubusercontent.com/rpizarrog/FundamentosMachineLearning/master/datos/melb_data.csv'
df = pd.read_csv(ruta)

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df = df.select_dtypes(exclude=['object'])

# %%
#Buscar nulos
df.isnull().sum()
# Out:
# Rooms               0
# Price               0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# Lattitude           0
# Longtitude          0
# Propertycount       0
# dtype: int64

# %%
#Histograma
df.Price.hist(color='firebrick', bins=30, figsize=(10, 6))

# %%
#Borrado de datos nulos
df = df.dropna()
df
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6830 rows x 13 columns]

# %%
#Datos con área menor o igual a 800
df0 = df[df["BuildingArea"]<=800]

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df0.plot(x = 'BuildingArea', y = 'Price', c = 'navy', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y area construida');

# %%
#Datos con área cero
dfzero = df0[df0["BuildingArea"]<=15]
len(dfzero)
# Out:
# 56

# %%
#Se eliminan los registros de menos de 15 mts cuadrados de area
df0 = df0[df0["BuildingArea"]>15]

# %%
#Se eliminan todos los datos que estén más allá de 3 desviaciones estándar
#df0 = df0[(np.abs(zscore(df0['BuildingArea']))<=3)]
df0 = df0[(np.abs(zscore(df0['Price']))<=3)]
df0
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# 6          3  1876000.0       2.5    3067.0       4.0       2.0  0.0
# 7          2  1636000.0       2.5    3067.0       2.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13572      2   650000.0      14.5    3087.0       2.0       1.0  1.0
# 13573      4   635000.0      14.7    3030.0       4.0       2.0  1.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  Propertycount
# 1         156.0          79.0     1900.0  -37.80790   144.99340         4019.0
# 2         134.0         150.0     1900.0  -37.80930   144.99440         4019.0
# 4         120.0         142.0     2014.0  -37.80720   144.99410         4019.0
# 6         245.0         210.0     1910.0  -37.80240   144.99930         4019.0
# 7         256.0         107.0     1890.0  -37.80600   144.99540         4019.0
# ...         ...           ...        ...        ...         ...            ...
# 13572     210.0          79.0     2006.0  -37.70657   145.07878         2329.0
# 13573     662.0         172.0     1980.0  -37.89327   144.64789        16166.0
# 13576     333.0         133.0     1995.0  -37.85927   144.87904         6380.0
# 13578     866.0         157.0     1920.0  -37.85908   144.89299         6380.0
# 13579     362.0         112.0     1920.0  -37.81188   144.88449         6543.0
#
# [6654 rows x 13 columns]

# %%
#Boxplot
ax = sb.boxplot(data=df0['BuildingArea'].values, orient='h', color='yellow')
ax.set_title('Boxplot area construida');
plt.show()

# %%
#Múltiples diagramas por parejas
#sb.set_theme(style="ticks")
sb.pairplot(df0, hue='Rooms')

# %%
#Correlación entre variables
corr_test = pearsonr(x = df['BuildingArea'], y = df['Price'])
print("Coeficiente de correlación de Pearson: ", corr_test[0])
print("P-value: ", corr_test[1])
# Out:
# Coeficiente de correlación de Pearson:  0.5204915813803511
# P-value:  0.0

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(10, 10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sb.heatmap(df.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
df1 = df.copy()
for columna in df1:
  df1 = df1[(np.abs(zscore(df1[columna]))<=3)]

# %%
#Diagrama de distribución
fig, ax = plt.subplots(figsize=(10, 6))
df1.plot(x = 'BuildingArea', y = 'Price', c = 'navy', kind = "scatter", ax = ax)
ax.set_title('Distribución de precio y area construida');

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(10, 10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sb.heatmap(df1.astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
sb.pairplot(df1, kind='reg')

# %%
sb.set_theme(color_codes=True)
sb.set_theme(style="ticks")
ax = sb.regplot(x="Rooms", y="Car", data=df1, marker='+', x_jitter=0.2, y_jitter=0.2)
ax.set_title('Distribución de precio y area construida');

# %%
#Regresión lineal (Area construida vs. Precio)
x = df1["BuildingArea"]
y = df1["Price"]
x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     3877.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        13:26:28   Log-Likelihood:                -86205.
# No. Observations:                6005   AIC:                         1.724e+05
# Df Residuals:                    6003   BIC:                         1.724e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         3.254e+05   1.27e+04     25.652      0.000    3.01e+05     3.5e+05
# BuildingArea  5345.7152     85.855     62.265      0.000    5177.409    5514.021
# ==============================================================================
# Omnibus:                      921.026   Durbin-Watson:                   1.421
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1990.795
# Skew:                           0.909   Prob(JB):                         0.00
# Kurtosis:                       5.157   Cond. No.                         350.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
df1.dtypes
# Out:
# Rooms              int64
# Price            float64
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# Lattitude        float64
# Longtitude       float64
# Propertycount    float64
# dtype: object

# %%
#Regresión lineal múltiple
#x = df1.iloc[:,[0,2,4,5,6,7,8,9,12]]
x = df1.iloc[:,[2,4,5,6,7,8,9,12]]
y = df1["Price"]
x2 = sm.add_constant(x)
est = sm.OLS(y, x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     1185.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        13:26:35   Log-Likelihood:                -84854.
# No. Observations:                6005   AIC:                         1.697e+05
# Df Residuals:                    5996   BIC:                         1.698e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          9.876e+06   2.55e+05     38.709      0.000    9.38e+06    1.04e+07
# Distance      -2.725e+04   1099.221    -24.794      0.000   -2.94e+04   -2.51e+04
# Bedroom2       7.959e+04   7593.945     10.481      0.000    6.47e+04    9.45e+04
# Bathroom       1.394e+05   9554.083     14.594      0.000    1.21e+05    1.58e+05
# Car            4.655e+04   6042.410      7.705      0.000    3.47e+04    5.84e+04
# Landsize        113.0368     13.673      8.267      0.000      86.234     139.840
# BuildingArea   3780.7616    109.739     34.452      0.000    3565.634    3995.890
# YearBuilt     -4933.6289    130.630    -37.768      0.000   -5189.710   -4677.548
# Propertycount     5.8177      1.199      4.853      0.000       3.468       8.168
# ==============================================================================
# Omnibus:                      873.038   Durbin-Watson:                   1.481
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2051.442
# Skew:                           0.839   Prob(JB):                         0.00
# Kurtosis:                       5.321   Cond. No.                     4.80e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
#Predicciones con scikit-learn
train, test = train_test_split(df1, test_size = 0.10)
print("Ejemplos usados para entrenar: ", len(train))
print("Ejemplos usados para test: ", len(test))
# Out:
# Ejemplos usados para entrenar:  5404
# Ejemplos usados para test:  601

# %%
#Se definen las variables
x_train = train.iloc[:,[2,4,5,6,7,8,9,12]]
y_train = train.Price
x_test = test.iloc[:,[2,4,5,6,7,8,9,12]]
y_test = test.Price

# %%
#Entrenamiento del modelo
regr = LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train
# Out:
# 3484      770000.0
# 10768    1850000.0
# 12240    2515000.0
# 854      1100000.0
# 4895      496000.0
#            ...
# 938       715000.0
# 5571      742000.0
# 13348    2800000.0
# 2264      300000.0
# 12049     750000.0
# Name: Price, Length: 5404, dtype: float64

# %%
#Predicción
y_pred = regr.predict(x_train)
y_pred
# Out:
# array([1249920.0888303 ,  980562.97439329, 2119429.06587345, ...,
#         879588.40632126,  540223.81264895, 1373094.61415835])

# %%
print('Coeficientes:\n', regr.coef_)
print("Error cuadrático medio (Mean squared error): %.2f" % mean_squared_error(y_train, y_pred))
print('Varianza: %.2f' % r2_score(y_train, y_pred))
print('w = ' + str(regr.coef_) + ', b = ' + str(regr.intercept_))
# Out:
# Coeficientes:
#  [-2.70495716e+04  7.67462529e+04  1.36628158e+05  4.74626218e+04
#   1.15229074e+02  3.81578537e+03 -4.93857646e+03  5.22048280e+00]
# Error cuadrático medio (Mean squared error): 110416127386.83
# Varianza: 0.61
# w = [-2.70495716e+04  7.67462529e+04  1.36628158e+05  4.74626218e+04
#   1.15229074e+02  3.81578537e+03 -4.93857646e+03  5.22048280e+00], b = 9893735.834799152

# %%
predicciones = regr.predict(x_train)
for y, y_pred in list(zip(y_train, predicciones)) [:10]:
    print("Valor real: {:.2f} - Valor estimado: {:.2f}".format(y, y_pred))
# Out:
# Valor real: 770000.00 - Valor estimado: 1249920.09
# Valor real: 1850000.00 - Valor estimado: 980562.97
# Valor real: 2515000.00 - Valor estimado: 2119429.07
# Valor real: 1100000.00 - Valor estimado: 1062378.97
# Valor real: 496000.00 - Valor estimado: 722958.86
# Valor real: 603000.00 - Valor estimado: 605877.84
# Valor real: 2650000.00 - Valor estimado: 1819423.11
# Valor real: 990000.00 - Valor estimado: 1207072.24
# Valor real: 1900000.00 - Valor estimado: 2321088.05
# Valor real: 1338000.00 - Valor estimado: 1190118.70

# %%
predicciones = regr.predict(X=x_test)
print(predicciones[0:10,])
rmse = mean_squared_error(y_true=y_test, y_pred=predicciones, squared=False)
print(f"\nEl error (rmse) del test es: {rmse}")
# Out:
# [ 490099.07891136  996527.33677525  627686.4993389   897499.69361348
#  1341823.81752382 1371786.66662375  403116.85257456 1550996.75227097
#  1501943.0563412  1406686.11440564]
#
# El error (rmse) del test es: 325506.3083767527

# %% [markdown]
# **Taller N° 5**

# %%
#Regresión lineal (Area construida vs. Precio)

r2s = []
var = 0

for i in df1:
  if i != "Price":
    x = df1[i]
    y = df1["Price"]
    x2 = sm.add_constant(x)
    est = sm.OLS(y, x2)
    est2 = est.fit()
    r2 = est2.rsquared
    r2s.append(r2)
    if (max(r2s) == r2):
      var = i
    print("R² =" , r2)
    sb.set_theme(color_codes=True)
    sb.set_theme(style="ticks")
    ax = sb.regplot(x=i, y="Price", data=df1)
    ax.set_title(f'Distribución de precio y {i}')
    plt.show()

print("\nMayor R²:", max(r2s))
print("Distribución de precio y", var)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.3059040002009643
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.011388038368502995
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.076531315081656
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.29362359209276345
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.20964108459062203
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.059913577625664516
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.05967212148873868
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.39240185180401554
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.1339077107444785
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.06286427674741613
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.05717495634719494
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# R² = 0.00026499187087847265
# Mayor R²: 0.39240185180401554
# Distribución de precio y BuildingArea

# %% [markdown]
# **Regresiones Lineales Múltiples**

# %%
#Regresión lineal (Distribución Área de Construcción vs. Año de Construcción vs. Precio)

r2s = []
ies = []
var = 0
var2 = 0

for i in df1:
  for j in df1:
    if i != "Price":
      if j != "Price":
        if j != i:
          if (j in ies) == False:
            x = df1[i]
            y = df1["Price"]
            z = df1[j]

            ies.append(i)

            mod = smf.ols('y ~ x + z', data=df1).fit()
            print(mod.summary())
            r2 = mod.rsquared
            r2s.append(r2)

            if (max(r2s) == r2):
              var = i
              var2 = j

print("\nMayor R²:", max(r2s))
print("Distribución de precio,", var, "y", var2)
print(len(r2s))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     2014.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86160.
# No. Observations:                6005   AIC:                         1.723e+05
# Df Residuals:                    6002   BIC:                         1.723e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.761e+05   1.85e+04     14.932      0.000     2.4e+05    3.12e+05
# x            3.86e+05   6170.120     62.560      0.000    3.74e+05    3.98e+05
# z          -3.782e+04   1220.739    -30.980      0.000   -4.02e+04   -3.54e+04
# ==============================================================================
# Omnibus:                      937.575   Durbin-Watson:                   1.396
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1699.445
# Skew:                           0.995   Prob(JB):                         0.00
# Kurtosis:                       4.683   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.383
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     1866.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86249.
# No. Observations:                6005   AIC:                         1.725e+05
# Df Residuals:                    6002   BIC:                         1.725e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.456e+06   2.76e+05    -27.020      0.000      -8e+06   -6.92e+06
# x           3.226e+05   5903.065     54.656      0.000    3.11e+05    3.34e+05
# z           2443.1923     88.945     27.468      0.000    2268.828    2617.557
# ==============================================================================
# Omnibus:                      857.571   Durbin-Watson:                   1.419
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1454.188
# Skew:                           0.951   Prob(JB):                         0.00
# Kurtosis:                       4.481   Cond. No.                     1.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.307
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     1331.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86599.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6002   BIC:                         1.732e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.003e+05   1.91e+04      5.238      0.000    6.27e+04    1.38e+05
# x            2.47e+05   2.27e+04     10.873      0.000    2.02e+05    2.92e+05
# z           7.834e+04   2.28e+04      3.437      0.001    3.37e+04    1.23e+05
# ==============================================================================
# Omnibus:                      901.878   Durbin-Watson:                   1.314
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1534.493
# Skew:                           0.993   Prob(JB):                         0.00
# Kurtosis:                       4.480   Cond. No.                         24.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.333
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     1497.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86486.
# No. Observations:                6005   AIC:                         1.730e+05
# Df Residuals:                    6002   BIC:                         1.730e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.511e+04   1.91e+04      2.363      0.018    7680.346    8.25e+04
# x           2.527e+05   7592.613     33.282      0.000    2.38e+05    2.68e+05
# z            1.72e+05   1.11e+04     15.548      0.000     1.5e+05    1.94e+05
# ==============================================================================
# Omnibus:                      857.457   Durbin-Watson:                   1.350
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1421.005
# Skew:                           0.963   Prob(JB):                    2.71e-309
# Kurtosis:                       4.404   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.306
# Method:                 Least Squares   F-statistic:                     1324.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86604.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6002   BIC:                         1.732e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.033e+05   1.93e+04      5.348      0.000    6.54e+04    1.41e+05
# x           3.182e+05   6894.885     46.148      0.000    3.05e+05    3.32e+05
# z           1.047e+04   7680.345      1.364      0.173   -4581.296    2.55e+04
# ==============================================================================
# Omnibus:                      907.059   Durbin-Watson:                   1.313
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1542.868
# Skew:                           0.998   Prob(JB):                         0.00
# Kurtosis:                       4.477   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     1342.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86591.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6002   BIC:                         1.732e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.059e+05    1.9e+04      5.576      0.000    6.87e+04    1.43e+05
# x           3.101e+05   6662.407     46.541      0.000    2.97e+05    3.23e+05
# z             91.0686     17.466      5.214      0.000      56.830     125.307
# ==============================================================================
# Omnibus:                      886.371   Durbin-Watson:                   1.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1487.630
# Skew:                           0.985   Prob(JB):                         0.00
# Kurtosis:                       4.437   Cond. No.                     1.86e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.86e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     2087.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86116.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6002   BIC:                         1.723e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.587e+05   1.76e+04      9.009      0.000    1.24e+05    1.93e+05
# x           1.153e+05   8583.414     13.431      0.000    9.85e+04    1.32e+05
# z           4095.7600    125.769     32.566      0.000    3849.208    4342.312
# ==============================================================================
# Omnibus:                      830.160   Durbin-Watson:                   1.346
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1585.035
# Skew:                           0.874   Prob(JB):                         0.00
# Kurtosis:                       4.811   Cond. No.                         524.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.416
# Method:                 Least Squares   F-statistic:                     2141.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86085.
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6002   BIC:                         1.722e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9.627e+06   2.83e+05     34.016      0.000    9.07e+06    1.02e+07
# x           3.101e+05   5754.332     53.892      0.000    2.99e+05    3.21e+05
# z          -4831.2105    143.364    -33.699      0.000   -5112.255   -4550.166
# ==============================================================================
# Omnibus:                     1060.671   Durbin-Watson:                   1.380
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2161.909
# Skew:                           1.056   Prob(JB):                         0.00
# Kurtosis:                       5.045   Cond. No.                     1.06e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.379
# Model:                            OLS   Adj. R-squared:                  0.379
# Method:                 Least Squares   F-statistic:                     1834.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86269.
# No. Observations:                6005   AIC:                         1.725e+05
# Df Residuals:                    6002   BIC:                         1.726e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.898e+07   2.97e+06    -26.618      0.000   -8.48e+07   -7.32e+07
# x           3.279e+05   5926.293     55.325      0.000    3.16e+05    3.39e+05
# z          -2.091e+06   7.85e+04    -26.655      0.000   -2.25e+06   -1.94e+06
# ==============================================================================
# Omnibus:                      929.420   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1689.184
# Skew:                           0.986   Prob(JB):                         0.00
# Kurtosis:                       4.692   Cond. No.                     2.08e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     1529.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86465.
# No. Observations:                6005   AIC:                         1.729e+05
# Df Residuals:                    6002   BIC:                         1.730e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.511e+08   8.93e+06    -16.913      0.000   -1.69e+08   -1.34e+08
# x           3.104e+05   6158.148     50.398      0.000    2.98e+05    3.22e+05
# z           1.043e+06   6.16e+04     16.925      0.000    9.22e+05    1.16e+06
# ==============================================================================
# Omnibus:                      954.278   Durbin-Watson:                   1.375
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1699.875
# Skew:                           1.020   Prob(JB):                         0.00
# Kurtosis:                       4.623   Cond. No.                     2.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     1369.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86573.
# No. Observations:                6005   AIC:                         1.732e+05
# Df Residuals:                    6002   BIC:                         1.732e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1401.2418   2.31e+04      0.061      0.952   -4.38e+04    4.66e+04
# x           3.285e+05   6278.862     52.311      0.000    3.16e+05    3.41e+05
# z             12.6686      1.573      8.056      0.000       9.586      15.751
# ==============================================================================
# Omnibus:                      920.405   Durbin-Watson:                   1.326
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1594.232
# Skew:                           1.001   Prob(JB):                         0.00
# Kurtosis:                       4.536   Cond. No.                     3.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     337.8
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          9.53e-140
# Time:                        14:39:19   Log-Likelihood:                -87381.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.748e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.051e+06   3.36e+05    -21.016      0.000   -7.71e+06   -6.39e+06
# x          -1.837e+04   1431.708    -12.828      0.000   -2.12e+04   -1.56e+04
# z           2669.8538    109.036     24.486      0.000    2456.104    2883.604
# ==============================================================================
# Omnibus:                      666.070   Durbin-Watson:                   1.569
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              967.924
# Skew:                           0.841   Prob(JB):                    6.58e-211
# Kurtosis:                       4.019   Cond. No.                     1.59e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     1911.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86222.
# No. Observations:                6005   AIC:                         1.724e+05
# Df Residuals:                    6002   BIC:                         1.725e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.982e+05   1.86e+04     16.049      0.000    2.62e+05    3.35e+05
# x          -3.785e+04   1235.877    -30.628      0.000   -4.03e+04   -3.54e+04
# z           3.817e+05   6265.753     60.918      0.000    3.69e+05    3.94e+05
# ==============================================================================
# Omnibus:                      936.948   Durbin-Watson:                   1.418
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1687.115
# Skew:                           0.998   Prob(JB):                         0.00
# Kurtosis:                       4.662   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.243
# Method:                 Least Squares   F-statistic:                     962.2
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86866.
# No. Observations:                6005   AIC:                         1.737e+05
# Df Residuals:                    6002   BIC:                         1.738e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.055e+05   1.86e+04     32.485      0.000    5.69e+05    6.42e+05
# x          -2.125e+04   1311.023    -16.208      0.000   -2.38e+04   -1.87e+04
# z           4.134e+05   9652.200     42.827      0.000    3.94e+05    4.32e+05
# ==============================================================================
# Omnibus:                      762.584   Durbin-Watson:                   1.546
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1132.287
# Skew:                           0.933   Prob(JB):                    1.34e-246
# Kurtosis:                       4.021   Cond. No.                         35.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     327.1
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          1.41e-135
# Time:                        14:39:19   Log-Likelihood:                -87391.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.748e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9.574e+05   1.69e+04     56.701      0.000    9.24e+05    9.91e+05
# x          -2.384e+04   1491.701    -15.983      0.000   -2.68e+04   -2.09e+04
# z            2.02e+05   8398.589     24.051      0.000    1.86e+05    2.18e+05
# ==============================================================================
# Omnibus:                      840.363   Durbin-Watson:                   1.494
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1264.104
# Skew:                           1.014   Prob(JB):                    3.19e-275
# Kurtosis:                       3.969   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     319.3
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          1.60e-132
# Time:                        14:39:19   Log-Likelihood:                -87398.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.748e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.069e+06   1.52e+04     70.337      0.000    1.04e+06     1.1e+06
# x          -2.314e+04   1485.963    -15.570      0.000    -2.6e+04   -2.02e+04
# z            467.2065     19.689     23.729      0.000     428.608     505.805
# ==============================================================================
# Omnibus:                      619.824   Durbin-Watson:                   1.477
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1015.854
# Skew:                           0.738   Prob(JB):                    2.57e-221
# Kurtosis:                       4.373   Cond. No.                     1.24e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.469
# Method:                 Least Squares   F-statistic:                     2647.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -85802.
# No. Observations:                6005   AIC:                         1.716e+05
# Df Residuals:                    6002   BIC:                         1.716e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.495e+05   1.41e+04     38.955      0.000    5.22e+05    5.77e+05
# x          -3.293e+04   1121.464    -29.360      0.000   -3.51e+04   -3.07e+04
# z           5969.8207     83.056     71.877      0.000    5807.002    6132.640
# ==============================================================================
# Omnibus:                     1002.196   Durbin-Watson:                   1.517
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2551.382
# Skew:                           0.922   Prob(JB):                         0.00
# Kurtosis:                       5.607   Cond. No.                         417.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     464.1
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          3.81e-188
# Time:                        14:39:19   Log-Likelihood:                -87270.
# No. Observations:                6005   AIC:                         1.745e+05
# Df Residuals:                    6002   BIC:                         1.746e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.142e+07   3.53e+05     32.397      0.000    1.07e+07    1.21e+07
# x           -682.8205   1440.371     -0.474      0.635   -3506.465    2140.824
# z          -5285.9721    181.380    -29.143      0.000   -5641.543   -4930.401
# ==============================================================================
# Omnibus:                     1090.561   Durbin-Watson:                   1.496
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1942.480
# Skew:                           1.156   Prob(JB):                         0.00
# Kurtosis:                       4.555   Cond. No.                     1.08e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.077
# Method:                 Least Squares   F-statistic:                     253.2
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          2.76e-106
# Time:                        14:39:19   Log-Likelihood:                -87458.
# No. Observations:                6005   AIC:                         1.749e+05
# Df Residuals:                    6002   BIC:                         1.749e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.409e+07   3.62e+06    -20.470      0.000   -8.12e+07    -6.7e+07
# x          -1.411e+04   1430.960     -9.859      0.000   -1.69e+04   -1.13e+04
# z          -1.991e+06   9.58e+04    -20.790      0.000   -2.18e+06    -1.8e+06
# ==============================================================================
# Omnibus:                      746.982   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1096.109
# Skew:                           0.925   Prob(JB):                    9.62e-239
# Kurtosis:                       3.980   Cond. No.                     2.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.096
# Model:                            OLS   Adj. R-squared:                  0.095
# Method:                 Least Squares   F-statistic:                     317.1
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          1.26e-131
# Time:                        14:39:19   Log-Likelihood:                -87400.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.748e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.583e+08    1.1e+07    -23.529      0.000    -2.8e+08   -2.37e+08
# x          -2.389e+04   1497.200    -15.960      0.000   -2.68e+04    -2.1e+04
# z            1.79e+06   7.57e+04     23.634      0.000    1.64e+06    1.94e+06
# ==============================================================================
# Omnibus:                      787.948   Durbin-Watson:                   1.583
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1187.799
# Skew:                           0.950   Prob(JB):                    1.18e-258
# Kurtosis:                       4.066   Cond. No.                     2.44e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     34.64
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):           1.10e-15
# Time:                        14:39:19   Log-Likelihood:                -87667.
# No. Observations:                6005   AIC:                         1.753e+05
# Df Residuals:                    6002   BIC:                         1.754e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.162e+06   2.22e+04     52.253      0.000    1.12e+06    1.21e+06
# x          -1.241e+04   1508.062     -8.226      0.000   -1.54e+04   -9448.930
# z             -0.7028      1.909     -0.368      0.713      -4.445       3.039
# ==============================================================================
# Omnibus:                      891.395   Durbin-Watson:                   1.480
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1367.099
# Skew:                           1.058   Prob(JB):                    1.37e-297
# Kurtosis:                       3.995   Cond. No.                     2.56e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     1766.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86312.
# No. Observations:                6005   AIC:                         1.726e+05
# Df Residuals:                    6002   BIC:                         1.727e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.395e+06   2.79e+05    -26.526      0.000   -7.94e+06   -6.85e+06
# x           2431.6363     89.878     27.055      0.000    2255.442    2607.830
# z           3.167e+05   5983.249     52.929      0.000    3.05e+05    3.28e+05
# ==============================================================================
# Omnibus:                      865.376   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1470.353
# Skew:                           0.958   Prob(JB):                         0.00
# Kurtosis:                       4.486   Cond. No.                     1.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.265
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     1080.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:19   Log-Likelihood:                -86778.
# No. Observations:                6005   AIC:                         1.736e+05
# Df Residuals:                    6002   BIC:                         1.736e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5.926e+06   3.01e+05    -19.684      0.000   -6.52e+06   -5.34e+06
# x           2067.5912     97.567     21.191      0.000    1876.325    2258.858
# z           3.696e+05   9431.980     39.186      0.000    3.51e+05    3.88e+05
# ==============================================================================
# Omnibus:                      744.112   Durbin-Watson:                   1.589
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1085.390
# Skew:                           0.926   Prob(JB):                    2.04e-236
# Kurtosis:                       3.951   Cond. No.                     1.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     463.1
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          9.34e-188
# Time:                        14:39:19   Log-Likelihood:                -87270.
# No. Observations:                6005   AIC:                         1.745e+05
# Df Residuals:                    6002   BIC:                         1.746e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.573e+06   3.26e+05    -20.136      0.000   -7.21e+06   -5.93e+06
# x           2383.9674    105.453     22.607      0.000    2177.242    2590.692
# z           1.551e+05   7795.893     19.898      0.000     1.4e+05     1.7e+05
# ==============================================================================
# Omnibus:                      818.906   Durbin-Watson:                   1.551
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1225.444
# Skew:                           0.993   Prob(JB):                    7.91e-267
# Kurtosis:                       3.977   Cond. No.                     1.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+05. This might indicate that there are
# ...
# No. Observations:                6005   AIC:                         1.722e+05
# Df Residuals:                    6002   BIC:                         1.722e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -1.35e+08    8.4e+06    -16.084      0.000   -1.51e+08   -1.19e+08
# x           5167.5346     84.784     60.949      0.000    5001.327    5333.742
# z           9.337e+05   5.79e+04     16.123      0.000     8.2e+05    1.05e+06
# ==============================================================================
# Omnibus:                      964.397   Durbin-Watson:                   1.469
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2113.569
# Skew:                           0.942   Prob(JB):                         0.00
# Kurtosis:                       5.214   Cond. No.                     3.23e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.23e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.399
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     1993.
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:39:20   Log-Likelihood:                -86172.
# No. Observations:                6005   AIC:                         1.723e+05
# Df Residuals:                    6002   BIC:                         1.724e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    2.32e+05    1.7e+04     13.645      0.000    1.99e+05    2.65e+05
# x           5419.1045     85.853     63.121      0.000    5250.802    5587.407
# z             12.0313      1.467      8.199      0.000       9.155      14.908
# ==============================================================================
# Omnibus:                      930.018   Durbin-Watson:                   1.437
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2050.660
# Skew:                           0.909   Prob(JB):                         0.00
# Kurtosis:                       5.211   Cond. No.                     2.50e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.5e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.187
# Model:                            OLS   Adj. R-squared:                  0.187
# Method:                 Least Squares   F-statistic:                     690.4
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          1.32e-270
# Time:                        14:39:20   Log-Likelihood:                -87080.
# No. Observations:                6005   AIC:                         1.742e+05
# Df Residuals:                    6002   BIC:                         1.742e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5.621e+07   3.43e+06    -16.373      0.000   -6.29e+07   -4.95e+07
# x          -5121.2620    169.141    -30.278      0.000   -5452.838   -4789.686
# z           -1.78e+06   8.99e+04    -19.806      0.000   -1.96e+06    -1.6e+06
# ==============================================================================
# Omnibus:                      982.663   Durbin-Watson:                   1.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1727.510
# Skew:                           1.055   Prob(JB):                         0.00
# Kurtosis:                       4.567   Cond. No.                     1.09e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.09e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     718.8
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          1.45e-280
# Time:                        14:39:20   Log-Likelihood:                -87057.
# No. Observations:                6005   AIC:                         1.741e+05
# Df Residuals:                    6002   BIC:                         1.741e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.943e+08    9.8e+06    -19.825      0.000   -2.14e+08   -1.75e+08
# x          -5352.4772    168.241    -31.814      0.000   -5682.290   -5022.664
# z            1.42e+06   6.76e+04     21.007      0.000    1.29e+06    1.55e+06
# ==============================================================================
# Omnibus:                     1072.697   Durbin-Watson:                   1.600
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1963.439
# Skew:                           1.121   Prob(JB):                         0.00
# Kurtosis:                       4.680   Cond. No.                     3.12e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.12e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     464.0
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          4.24e-188
# Time:                        14:39:20   Log-Likelihood:                -87270.
# No. Observations:                6005   AIC:                         1.745e+05
# Df Residuals:                    6002   BIC:                         1.746e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.147e+07   3.43e+05     33.392      0.000    1.08e+07    1.21e+07
# x          -5310.6882    174.505    -30.433      0.000   -5652.781   -4968.595
# z             -0.1936      1.754     -0.110      0.912      -3.632       3.245
# ==============================================================================
# Omnibus:                     1094.428   Durbin-Watson:                   1.497
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1953.014
# Skew:                           1.159   Prob(JB):                         0.00
# Kurtosis:                       4.560   Cond. No.                     4.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     292.7
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          4.92e-122
# Time:                        14:39:20   Log-Likelihood:                -87422.
# No. Observations:                6005   AIC:                         1.748e+05
# Df Residuals:                    6002   BIC:                         1.749e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      -2e+08   1.04e+07    -19.206      0.000    -2.2e+08    -1.8e+08
# x          -1.466e+06   1.01e+05    -14.451      0.000   -1.67e+06   -1.27e+06
# z           1.004e+06   7.67e+04     13.090      0.000    8.54e+05    1.15e+06
# ==============================================================================
# Omnibus:                      839.497   Durbin-Watson:                   1.598
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1288.964
# Skew:                           0.994   Prob(JB):                    1.27e-280
# Kurtosis:                       4.095   Cond. No.                     2.38e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.38e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     201.3
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):           2.38e-85
# Time:                        14:39:20   Log-Likelihood:                -87506.
# No. Observations:                6005   AIC:                         1.750e+05
# Df Residuals:                    6002   BIC:                         1.750e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.203e+07   3.65e+06    -19.742      0.000   -7.92e+07   -6.49e+07
# x          -1.933e+06   9.65e+04    -20.023      0.000   -2.12e+06   -1.74e+06
# z              0.2056      1.826      0.113      0.910      -3.374       3.785
# ==============================================================================
# Omnibus:                      842.737   Durbin-Watson:                   1.550
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1284.267
# Skew:                           1.004   Prob(JB):                    1.33e-279
# Kurtosis:                       4.048   Cond. No.                     4.30e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     182.3
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):           1.39e-77
# Time:                        14:39:20   Log-Likelihood:                -87524.
# No. Observations:                6005   AIC:                         1.751e+05
# Df Residuals:                    6002   BIC:                         1.751e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.019e+08   1.07e+07    -18.954      0.000   -2.23e+08   -1.81e+08
# x             1.4e+06   7.35e+04     19.050      0.000    1.26e+06    1.54e+06
# z             -1.3990      1.839     -0.761      0.447      -5.004       2.206
# ==============================================================================
# Omnibus:                      926.772   Durbin-Watson:                   1.564
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1460.264
# Skew:                           1.073   Prob(JB):                         0.00
# Kurtosis:                       4.110   Cond. No.                     1.25e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Mayor R²: 0.5364135126225607
# Distribución de precio, BuildingArea y YearBuilt
# 66
